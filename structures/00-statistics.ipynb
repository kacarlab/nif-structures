# %% [markdown]
# # 00 - MAssive Nitrogenase prediction statistics

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
structure_info = pd.read_csv('reference.csv')

# %%
structure_info[['variant', 'id']].groupby('variant').count()
# Out:
#           id
# variant
# ALT2     767
# ALT3     766
# ALT4     766
# ALT5     766
# ALTALL   765
# MAP      768
# WT       770

# %%
structure_info[['status', 'id']].groupby('status').count()
# Out:
#           id
# status
# gold    1538
# silver  3830

# %%
structure_info[['is_ancestral', 'id']].groupby('is_ancestral').count()
# Out:
#                 id
# is_ancestral
# False          770
# True          4598

# %%
structure_info['u'] = structure_info['original_name'].apply(lambda x : x.split('.')[0].replace('_001', '').replace('_alt2', '').replace('_alt3', '').replace('_alt4', '').replace('_alt5', '').replace('_altall', '').replace('_map', ''))

# %%
structure_info[['stochiometry', 'u', 'is_ancestral', 'id']].groupby(['stochiometry', 'u', 'is_ancestral'], as_index=False).count().to_csv('count.csv')

# %%
structure_info.query('u == "Anc_1206"')
# Out:
#                           original_name           id stochiometry  \
# 565      Anc_1206_map_001.rechained.pdb  nsdb-000566         DDKK
# 1146     Anc_1206_map_001.rechained.pdb  nsdb-001147           HH
# 1557  Anc_1206_altall_001.rechained.pdb  nsdb-001558         DDKK
# 2237    Anc_1206_alt2_001.rechained.pdb  nsdb-002238         DDKK
# 2544    Anc_1206_alt4_001.rechained.pdb  nsdb-002545         DDKK
# 3220    Anc_1206_alt5_001.rechained.pdb  nsdb-003221         DDKK
# 3259    Anc_1206_alt3_001.rechained.pdb  nsdb-003260         DDKK
# 3468  Anc_1206_altall_001.rechained.pdb  nsdb-003469           HH
# 4049    Anc_1206_alt2_001.rechained.pdb  nsdb-004050           HH
# 4256    Anc_1206_alt4_001.rechained.pdb  nsdb-004257           HH
# 4678    Anc_1206_alt5_001.rechained.pdb  nsdb-004679           HH
# 4701    Anc_1206_alt3_001.rechained.pdb  nsdb-004702           HH
#
#       average_pLDDT        taxond_id          lineage  scientific_name  \
# 565       94.940253     Anc_1206_map     Anc_1206_map     Anc_1206_map
# 1146      88.738974     Anc_1206_map     Anc_1206_map     Anc_1206_map
# 1557      93.348608  Anc_1206_altall  Anc_1206_altall  Anc_1206_altall
# 2237      93.223124    Anc_1206_alt2    Anc_1206_alt2    Anc_1206_alt2
# 2544      93.560968    Anc_1206_alt4    Anc_1206_alt4    Anc_1206_alt4
# 3220      93.668608    Anc_1206_alt5    Anc_1206_alt5    Anc_1206_alt5
# 3259      93.417548    Anc_1206_alt3    Anc_1206_alt3    Anc_1206_alt3
# 3468      88.305037  Anc_1206_altall  Anc_1206_altall  Anc_1206_altall
# 4049      88.479872    Anc_1206_alt2    Anc_1206_alt2    Anc_1206_alt2
# 4256      88.573810    Anc_1206_alt4    Anc_1206_alt4    Anc_1206_alt4
# 4678      88.373498    Anc_1206_alt5    Anc_1206_alt5    Anc_1206_alt5
# 4701      88.352088    Anc_1206_alt3    Anc_1206_alt3    Anc_1206_alt3
#
#       is_ancestral nitrogenase_type  status  \
# 565           True              Anc    gold
# 1146          True              Anc    gold
# 1557          True              Anc  silver
# 2237          True              Anc  silver
# 2544          True              Anc  silver
# 3220          True              Anc  silver
# 3259          True              Anc  silver
# 3468          True              Anc  silver
# 4049          True              Anc  silver
# 4256          True              Anc  silver
# 4678          True              Anc  silver
# 4701          True              Anc  silver
#
#                                chain_reference variant  clade         u
# 565   {'A': 'D', 'B': 'K', 'D': 'D', 'E': 'K'}     MAP  other  Anc_1206
# 1146                      {'A': 'H', 'B': 'H'}     MAP  other  Anc_1206
# 1557  {'A': 'D', 'B': 'K', 'D': 'D', 'E': 'K'}  ALTALL  other  Anc_1206
# 2237  {'A': 'D', 'B': 'K', 'D': 'D', 'E': 'K'}    ALT2  other  Anc_1206
# 2544  {'A': 'D', 'B': 'K', 'D': 'D', 'E': 'K'}    ALT4  other  Anc_1206
# 3220  {'A': 'D', 'B': 'K', 'D': 'D', 'E': 'K'}    ALT5  other  Anc_1206
# 3259  {'A': 'D', 'B': 'K', 'D': 'D', 'E': 'K'}    ALT3  other  Anc_1206
# 3468                      {'A': 'H', 'B': 'H'}  ALTALL  other  Anc_1206
# 4049                      {'A': 'H', 'B': 'H'}    ALT2  other  Anc_1206
# 4256                      {'A': 'H', 'B': 'H'}    ALT4  other  Anc_1206
# 4678                      {'A': 'H', 'B': 'H'}    ALT5  other  Anc_1206
# 4701                      {'A': 'H', 'B': 'H'}    ALT3  other  Anc_1206

# %%
structure_info.query('u == "Anc_820"').query('stochiometry == "DDKK"').sort_values(by="original_name")
# Out:
#                          original_name           id stochiometry  \
# 3160    Anc_820_alt2_001.rechained.pdb  nsdb-003161         DDKK
# 2031    Anc_820_alt3_001.rechained.pdb  nsdb-002032         DDKK
# 2635    Anc_820_alt5_001.rechained.pdb  nsdb-002636         DDKK
# 1607  Anc_820_altall_001.rechained.pdb  nsdb-001608         DDKK
# 698      Anc_820_map_001.rechained.pdb  nsdb-000699         DDKK
#
#       average_pLDDT       taxond_id         lineage scientific_name  \
# 3160      94.443344    Anc_820_alt2    Anc_820_alt2    Anc_820_alt2
# 2031      94.162046    Anc_820_alt3    Anc_820_alt3    Anc_820_alt3
# 2635      94.403828    Anc_820_alt5    Anc_820_alt5    Anc_820_alt5
# 1607      94.089081  Anc_820_altall  Anc_820_altall  Anc_820_altall
# 698       94.444840     Anc_820_map     Anc_820_map     Anc_820_map
#
#       is_ancestral nitrogenase_type  status  \
# 3160          True              Anc  silver
# 2031          True              Anc  silver
# 2635          True              Anc  silver
# 1607          True              Anc  silver
# 698           True              Anc    gold
#
#                                chain_reference variant  clade        u
# 3160  {'A': 'D', 'B': 'K', 'D': 'D', 'E': 'K'}    ALT2  other  Anc_820
# 2031  {'A': 'D', 'B': 'K', 'D': 'D', 'E': 'K'}    ALT3  other  Anc_820
# 2635  {'A': 'D', 'B': 'K', 'D': 'D', 'E': 'K'}    ALT5  other  Anc_820
# 1607  {'A': 'D', 'B': 'K', 'D': 'D', 'E': 'K'}  ALTALL  other  Anc_820
# 698   {'A': 'D', 'B': 'K', 'D': 'D', 'E': 'K'}     MAP  other  Anc_820
